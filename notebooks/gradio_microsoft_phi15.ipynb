# %%
# !pip install einops
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 KB 1.1 MB/s eta 0:00:00
# ...

# %%
import gradio as gr
import time
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("microsoft/phi-1_5", trust_remote_code=True, torch_dtype="auto")
tokenizer = AutoTokenizer.from_pretrained("microsoft/phi-1_5", trust_remote_code=True, torch_dtype="auto")
# Out:
# pytorch_model.bin: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2.84G/2.84G [01:31<00:00, 31.0MB/s]
# (…)-1_5/resolve/main/generation_config.json: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 69.0/69.0 [00:00<00:00, 367kB/s]
# ...

# %%
device = torch.device("cuda:0")
model.cuda()
print("Device:", device)
# Out:
# Device: cuda:0

# %%
def generate_text(query):
    inputs = tokenizer(query, 
                       return_tensors="pt", 
                       return_attention_mask=False).to('cuda')
    outputs = model.generate(**inputs, max_length=2048)
    text = tokenizer.batch_decode(outputs)[0]
    return text

# %%
output = generate_text("What is large language model?")
print(output)
# Out:
# What is large language model?
#
# A large language model is a type of machine learning model that is trained on a large corpus of text data. It is designed to generate text that is similar to the input text, based on the patterns and structures that are found in the input text.
#
# What is the purpose of a large language model?
#
# The purpose of a large language model is to generate text that is similar to the input text, based on the patterns and structures that are found in the input text. This can be useful for a variety of applications, such as generating news articles, generating product descriptions, and generating chatbot responses.
#
# How does a large language model work?
#
# ...

# %%
prompt = """Write me novel story about honey and bear."""

output = generate_text(prompt)
print(output)
# Out:
# Write me novel story about honey and bear.
#
# <|endofstory|>
# <|endoftext|>
#
# Once upon a time, in a small town called Greenville, there lived a young girl named Lily. Lily was a curious and adventurous girl who loved exploring the world around her. One sunny day, she decided to go on a hiking trip with her friends, Emma and Jack.
#
# As they embarked on their journey, Lily noticed that Emma was carrying a heavy backpack filled with snacks and water bottles. Lily, being a helpful and considerate friend, offered to carry Emma's backpack for her. She knew that Emma had injured her back recently and it would be difficult for her to carry the heavy load. Lily's act of kindness made Emma feel grateful and relieved.
#
# ...

# %% [markdown]
# #### Gradio Chatbot with microsoft/phi-1_5

# %%
with gr.Blocks() as demo:
    chatbot = gr.Chatbot()
    msg = gr.Textbox()
    clear = gr.ClearButton([msg, chatbot])

    def respond(message, chat_history):
        bot_message = generate_text(message)
        chat_history.append((message, bot_message))
        time.sleep(1)
        return "", chat_history

    msg.submit(respond, [msg, chatbot], [msg, chatbot])

demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ##### Output

# %% [markdown]
# Me:
#
#     Hi, what is your name?”
#
#
# Model:
#
#     “My name is Sarah,” the girl replied.
#
#     “Nice to meet you, Sarah. Do you want to play with me?”
#
#     “Sure,” Sarah said, smiling.
#
#     As they played together, Sarah noticed that the girl was very good at playing the piano. She asked her if she played any other instruments.
#
#     “I play the guitar,” the girl said.
#
#     “That’s cool! I’ve always wanted to learn how to play an instrument,” Sarah said.
#
#     “You should try it! It’s a lot of fun,” the girl said.
#
#     Sarah thought about it for a moment. She had never played an instrument before, but she was curious. She asked the girl if she could teach her how to play the guitar.
#
#     “Of course!” the girl said.
#
