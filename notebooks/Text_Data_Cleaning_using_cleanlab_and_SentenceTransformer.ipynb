# %% [markdown]
# <a href="https://colab.research.google.com/github/LxYuan0420/nlp/blob/main/notebooks/Text_Data_Cleaning_using_cleanlab_and_SentenceTransformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text Classification with Transformers and Datalab

# %% [markdown]
# In this 5-minute quickstart tutorial, we use cleanlab to find potential label errors in an intent classification dataset composed of (text) customer service requests at an online bank. We consider a subset of the [Banking77-OOS Dataset](https://arxiv.org/abs/2106.04564) containing 1,000 customer service requests which can be classified into 10 categories corresponding to the intent of the request. Cleanlab automatically identifies bad examples in our dataset, including mislabeled data, out-of-scope examples (outliers), or otherwise ambiguous examples. Consider filtering or correcting such bad examples before you dive deep into modeling your data!
#
# **Overview of what we'll do in this tutorial:**
#
# - Use a pretrained transformer model to extract the text embeddings from the customer service requests
#
# - Train a simple Logistic Regression model on the text embeddings to compute out-of-sample predicted probabilities
#
# - Run cleanlab's `Datalab` audit with these predictions and embeddings in order to identify problems like: label issues, outliers, and near duplicates in the dataset.

# %% [markdown]
# <div class="alert alert-info">
# Quickstart
# <br/>
#
# Already have (out-of-sample) `pred_probs` from a model trained on an existing set of labels? Maybe you have some numeric `features` as well? Run the code below to find any potential label errors in your dataset.
#
# <div  class=markdown markdown="1" style="background:white;margin:16px">
#
# ```ipython3
# from cleanlab import Datalab
#
# lab = Datalab(data=your_dataset, label_name="column_name_of_labels")
# lab.find_issues(pred_probs=your_pred_probs, features=your_features)
#
# lab.report()
# lab.get_issues()
# ```
#
# </div>
# </div>

# %% [markdown]
# ## 1. Install required dependencies

# %% [markdown]
# You can use `pip` to install all packages required for this tutorial as follows:
#
# ```ipython3
# !pip install sklearn sentence-transformers
# !pip install "cleanlab[datalab]"
# # Make sure to install the version corresponding to this tutorial
# # E.g. if viewing master branch documentation:
# #     !pip install git+https://github.com/cleanlab/cleanlab.git
# ```

# %%
# Package installation (hidden on docs.cleanlab.ai).
# If running on Colab, may want to use GPU (select: Runtime > Change runtime type > Hardware accelerator > GPU)
# Package versions we used:scikit-learn==1.2.0 sentence-transformers==2.2.2

dependencies = ["cleanlab", "sklearn", "sentence_transformers", "datasets"]

# Supress outputs that may appear if tensorflow happens to be improperly installed:
import os

os.environ["TOKENIZERS_PARALLELISM"] = "false"  # disable parallelism to avoid deadlocks with huggingface

if "google.colab" in str(get_ipython()):  # Check if it's running in Google Colab
    # %pip install cleanlab==v2.4.0
    cmd = ' '.join([dep for dep in dependencies if dep != "cleanlab"])
    # %pip install $cmd
else:
    missing_dependencies = []
    for dependency in dependencies:
        try:
            __import__(dependency)
        except ImportError:
            missing_dependencies.append(dependency)

    if len(missing_dependencies) > 0:
        print("Missing required dependencies:")
        print(*missing_dependencies, sep=", ")
        print("\nPlease install them before running the rest of this notebook.")

# %%
import re
import string
import pandas as pd
from sklearn.metrics import accuracy_score, log_loss
from sklearn.model_selection import cross_val_predict
from sklearn.linear_model import LogisticRegression
from sentence_transformers import SentenceTransformer

from cleanlab import Datalab

# %%
# This cell is hidden from docs.cleanlab.ai

import random
import numpy as np

pd.set_option("display.max_colwidth", None)

SEED = 123456  # for reproducibility
np.random.seed(SEED)
random.seed(SEED)

# %%
#!pip install watermark
# %reload_ext watermark

# %%
# !pip freeze | grep -E "trans|clean"
# Out:
# cleanlab==2.4.0
# google-cloud-translate==3.11.1
# sentence-transformers==2.2.2
# transformers==4.30.2

# %% [markdown]
# ## 2. Load and format the text dataset

# %%
data = pd.read_csv("https://s.cleanlab.ai/banking-intent-classification.csv")
data.head()
# Out:
#                                                                                                                                                                                      text  \
# 0                                                                                                                     i accidentally made a payment to a wrong account. what should i do?
# 1                                                                                                                     i no longer want to transfer funds, can we cancel that transaction?
# 2                                                                                                                                                             cancel my transfer, please.
# 3                                                                                                                                             i want to revert this mornings transaction.
# 4  i just realised i made the wrong payment yesterday. can you please change it to the right account? it's my rent payment and really really needs to be in the right account by tomorrow
#
#              label
# 0  cancel_transfer
# 1  cancel_transfer
# 2  cancel_transfer
# 3  cancel_transfer
# 4  cancel_transfer

# %%
raw_texts, labels = data["text"].values, data["label"].values
num_classes = len(set(labels))

print(f"This dataset has {num_classes} classes.")
print(f"Classes: {set(labels)}")
# Out:
# This dataset has 10 classes.
# Classes: {'visa_or_mastercard', 'card_about_to_expire', 'apple_pay_or_google_pay', 'beneficiary_not_allowed', 'card_payment_fee_charged', 'change_pin', 'supported_cards_and_currencies', 'getting_spare_card', 'cancel_transfer', 'lost_or_stolen_phone'}

# %%
from collections import Counter

print(Counter(labels))
# Out:
# Counter({'card_payment_fee_charged': 138, 'beneficiary_not_allowed': 111, 'cancel_transfer': 109, 'visa_or_mastercard': 98, 'card_about_to_expire': 98, 'supported_cards_and_currencies': 95, 'apple_pay_or_google_pay': 93, 'getting_spare_card': 90, 'change_pin': 88, 'lost_or_stolen_phone': 80})

# %% [markdown]
# Let's view the i-th example in the dataset:

# %%
i = 1  # change this to view other examples from the dataset
print(f"Example Label: {labels[i]}")
print(f"Example Text: {raw_texts[i]}")
# Out:
# Example Label: cancel_transfer
# Example Text: i no longer want to transfer funds, can we cancel that transaction?

# %% [markdown]
# The data is stored as two numpy arrays:
#
# 1. `raw_texts` stores the customer service requests utterances in text format
# 2. `labels` stores the intent categories (labels) for each example

# %% [markdown]
# <div class="alert alert-info">
# Bringing Your Own Data (BYOD)?
#
# You can easily replace the above with your own text dataset, and continue with the rest of the tutorial.
#
# </div>

# %% [markdown]
# Next we convert the text strings into vectors better suited as inputs for our ML models.
#
# We will use numeric representations from a pretrained Transformer model as embeddings of our text. The [Sentence Transformers](https://huggingface.co/docs/hub/sentence-transformers) library offers simple methods to compute these embeddings for text data. Here, we load the pretrained `electra-small-discriminator` model, and then run our data through network to extract a vector embedding of each example.

# %%
transformer = SentenceTransformer('google/electra-small-discriminator')
text_embeddings = transformer.encode(raw_texts)
# Out:
# Downloading (…)af769/.gitattributes:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading (…)e3c41af769/README.md:   0%|          | 0.00/2.21k [00:00<?, ?B/s]
# Downloading (…)c41af769/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/54.2M [00:00<?, ?B/s]
# Downloading (…)af769/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)e3c41af769/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/google_electra-small-discriminator. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/google_electra-small-discriminator were not used when initializing ElectraModel: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.weight', 'discriminator_predictions.dense.bias']
# - This IS expected if you are initializing ElectraModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# Our subsequent ML model will directly operate on elements of `text_embeddings` in order to classify the customer service requests.

# %% [markdown]
# ## 3. Define a classification model and compute out-of-sample predicted probabilities

# %% [markdown]
# A typical way to leverage pretrained networks for a particular classification task is to add a linear output layer and fine-tune the network parameters on the new data. However this can be computationally intensive. Alternatively, we can freeze the pretrained weights of the network and only train the output layer without having to rely on GPU(s). Here we do this conveniently by fitting a scikit-learn linear model on top of the extracted embeddings.
#
# To identify label issues, cleanlab requires a probabilistic prediction from your model for each datapoint. However these predictions will be _overfit_ (and thus unreliable) for datapoints the model was previously trained on. cleanlab is intended to only be used with **out-of-sample** predicted class probabilities, i.e. on datapoints held-out from the model during the training.
#
# Here we obtain out-of-sample predicted class probabilities for every example in our dataset using a Logistic Regression model with cross-validation.

# %%
model = LogisticRegression(max_iter=400)

pred_probs = cross_val_predict(model, text_embeddings, labels, method="predict_proba")

# %% [markdown]
# ## 4. Use cleanlab to find issues in your dataset

# %% [markdown]
# Given feature embeddings and the (out-of-sample) predicted class probabilities obtained from any model you have, cleanlab can quickly help you identify low-quality examples in your dataset.
#
# Here, we use cleanlab's `Datalab` to find issues in our data. Datalab offers several ways of loading the data; we’ll simply wrap the training features and noisy labels in a dictionary.

# %%
data_dict = {"texts": raw_texts, "labels": labels}

# %% [markdown]
# All that is need to audit your data is to call `find_issues()`. We pass in the predicted probabilities and the feature embeddings obtained above, but you do not necessarily need to provide all of this information depending on which types of issues you are interested in. The more inputs you provide, the more types of issues `Datalab` can detect in your data. Using a better model to produce these inputs will ensure cleanlab more accurately estimates issues.

# %%
lab = Datalab(data_dict, label_name="labels")
lab.find_issues(pred_probs=pred_probs, features=text_embeddings)
# Out:
# Finding label issues ...
# Finding outlier issues ...
# Fitting OOD estimator based on provided features ...
# Finding near_duplicate issues ...
# Audit complete. 87 issues found in the dataset.

# %% [markdown]
# After the audit is complete, review the findings using the `report` method:

# %%
lab.report()
# Out:
# Here is a summary of the different kinds of issues found in the data:
#
#     issue_type  num_issues
#          label          44
#        outlier          39
# near_duplicate           4
#
# Dataset Information: num_examples: 1000, num_classes: 10
#
#
# ----------------------- label issues -----------------------
#
# About this issue:
# 	Examples whose given label is estimated to be potentially incorrect
#     (e.g. due to annotation error) are flagged as having label issues.
#
#
# Number of examples with this issue: 44
# Overall dataset quality in terms of this issue: 0.9560
#
# Examples representing most severe instances of this issue:
#      is_label_issue  label_score              given_label           predicted_label
# 981            True     0.000005     card_about_to_expire  card_payment_fee_charged
# 974            True     0.000150  beneficiary_not_allowed                change_pin
# 982            True     0.000219  apple_pay_or_google_pay      card_about_to_expire
# 990            True     0.000325  apple_pay_or_google_pay   beneficiary_not_allowed
# 971            True     0.000511  beneficiary_not_allowed                change_pin
#
#
# ---------------------- outlier issues ----------------------
#
# About this issue:
# 	Examples that are very different from the rest of the dataset
#     (i.e. potentially out-of-distribution or rare/anomalous instances).
#
#
# Number of examples with this issue: 39
# Overall dataset quality in terms of this issue: 0.9120
#
# Examples representing most severe instances of this issue:
#      is_outlier_issue  outlier_score
# 994              True       0.676322
# 999              True       0.686193
# 989              True       0.711223
# 433              True       0.711974
# 990              True       0.713793
#
#
# ------------------ near_duplicate issues -------------------
#
# About this issue:
# 	A (near) duplicate issue refers to two or more examples in
#     a dataset that are extremely similar to each other, relative
#     to the rest of the dataset.  The examples flagged with this issue
#     may be exactly duplicated, or lie atypically close together when
#     represented as vectors (i.e. feature embeddings).
#
#
# Number of examples with this issue: 4
# Overall dataset quality in terms of this issue: 0.0657
#
# Examples representing most severe instances of this issue:
#      is_near_duplicate_issue  near_duplicate_score                                 near_duplicate_sets  distance_to_nearest_neighbor
# 160                     True              0.006237  [148, 219, 234, 118, 201, 223, 125, 140, 978, 172]                      0.006237
# 148                     True              0.006237  [160, 219, 234, 223, 140, 118, 201, 125, 229, 978]                      0.006237
# 546                     True              0.006485  [514, 523, 570, 569, 458, 528, 757, 137, 539, 827]                      0.006485
# 514                     True              0.006485  [546, 523, 570, 757, 761, 569, 528, 527, 458, 137]                      0.006485
# 481                    False              0.008164  [475, 493, 486, 849, 466, 845, 434, 795, 468, 834]                      0.008165

# %% [markdown]
# ### Label issues
#
# The report indicates that cleanlab identified many label issues in our dataset. We can see which examples are flagged as likely mislabeled and the label quality score for each example using the `get_issues` method, specifying `label` as an argument to focus on label issues in the data.

# %%
label_issues = lab.get_issues("label")
label_issues.head()
# Out:
#    is_label_issue  label_score      given_label          predicted_label
# 0           False     0.806106  cancel_transfer          cancel_transfer
# 1           False     0.271031  cancel_transfer          cancel_transfer
# 2           False     0.695446  cancel_transfer          cancel_transfer
# 3           False     0.179742  cancel_transfer  apple_pay_or_google_pay
# 4           False     0.822643  cancel_transfer          cancel_transfer

# %%
label_issues.shape
# Out:
# (1000, 4)

# %%
# low score means low confidence aka likely to be mislabeled
sorted_label_issues = label_issues.sort_values(["label_score"], ascending=[True])
sorted_label_issues.head()
# Out:
#      is_label_issue  label_score              given_label  \
# 981            True     0.000005     card_about_to_expire
# 974            True     0.000150  beneficiary_not_allowed
# 982            True     0.000219  apple_pay_or_google_pay
# 990            True     0.000325  apple_pay_or_google_pay
# 971            True     0.000511  beneficiary_not_allowed
#
#               predicted_label
# 981  card_payment_fee_charged
# 974                change_pin
# 982      card_about_to_expire
# 990   beneficiary_not_allowed
# 971                change_pin

# %% [markdown]
# This method returns a dataframe containing a label quality score for each example. These numeric scores lie between 0 and 1, where lower scores indicate examples more likely to be mislabeled. The dataframe also contains a boolean column specifying whether or not each example is identified to have a label issue (indicating it is likely mislabeled).

# %% [markdown]
# We can get the subset of examples flagged with label issues, and also sort by label quality score to find the indices of the 5 most likely mislabeled examples in our dataset.

# %%
identified_label_issues = label_issues[label_issues["is_label_issue"] == True]
lowest_quality_labels = label_issues["label_score"].argsort()[:55].to_numpy()

print(
    f"cleanlab found {len(identified_label_issues)} potential label errors in the dataset.\n"
    f"Here are indices of the top 5 most likely errors: \n {lowest_quality_labels}"
)
# Out:
# cleanlab found 44 potential label errors in the dataset.
# Here are indices of the top 5 most likely errors:
#  [981 974 982 990 971 997 980 978 989 998 985 987 983 966 119 991 950 964
#  994 970 984 992 977 963 652 993 367 962 972 973 959 436 979 976 960 988
#  957 958 412 612 699 967 591 965 961 954 547 968  81 480 756 558 999 502
#  557]

# %% [markdown]
# Let's review some of the most likely label errors.
#
# Here we display the top 15 examples identified as the most likely label errors in the dataset, together with their given (original) label and a suggested alternative label from cleanlab.

# %%
data_with_suggested_labels.head()
# Out:
#                                                                                                                                                                                      text  \
# 0                                                                                                                     i accidentally made a payment to a wrong account. what should i do?
# 1                                                                                                                     i no longer want to transfer funds, can we cancel that transaction?
# 2                                                                                                                                                             cancel my transfer, please.
# 3                                                                                                                                             i want to revert this mornings transaction.
# 4  i just realised i made the wrong payment yesterday. can you please change it to the right account? it's my rent payment and really really needs to be in the right account by tomorrow
#
#        given_label          suggested_label  label_score
# 0  cancel_transfer          cancel_transfer     0.806106
# 1  cancel_transfer          cancel_transfer     0.271031
# 2  cancel_transfer          cancel_transfer     0.695446
# 3  cancel_transfer  apple_pay_or_google_pay     0.179742
# 4  cancel_transfer          cancel_transfer     0.822643

# %%
# sample code to update specific idx/row's given label with suggested label
suggested_label = data_with_suggested_labels.loc[3, "suggested_label"]
data_with_suggested_labels.loc[3, "given_label"] = suggested_label

# %%
data_with_suggested_labels.head()
# Out:
#                                                                                                                                                                                      text  \
# 0                                                                                                                     i accidentally made a payment to a wrong account. what should i do?
# 1                                                                                                                     i no longer want to transfer funds, can we cancel that transaction?
# 2                                                                                                                                                             cancel my transfer, please.
# 3                                                                                                                                             i want to revert this mornings transaction.
# 4  i just realised i made the wrong payment yesterday. can you please change it to the right account? it's my rent payment and really really needs to be in the right account by tomorrow
#
#                given_label          suggested_label  label_score
# 0          cancel_transfer          cancel_transfer     0.806106
# 1          cancel_transfer          cancel_transfer     0.271031
# 2          cancel_transfer          cancel_transfer     0.695446
# 3  apple_pay_or_google_pay  apple_pay_or_google_pay     0.179742
# 4          cancel_transfer          cancel_transfer     0.822643

# %%
# before: drop idx 3
data_with_suggested_labels = data_with_suggested_labels.drop([3])

# %%
# after: drop idx
data_with_suggested_labels.head()
# Out:
#                                                                                                                                                                                      text  \
# 0                                                                                                                     i accidentally made a payment to a wrong account. what should i do?
# 1                                                                                                                     i no longer want to transfer funds, can we cancel that transaction?
# 2                                                                                                                                                             cancel my transfer, please.
# 4  i just realised i made the wrong payment yesterday. can you please change it to the right account? it's my rent payment and really really needs to be in the right account by tomorrow
# 5                                                                                                                                       i want to cancel a transaction from this morning.
#
#        given_label  suggested_label  label_score
# 0  cancel_transfer  cancel_transfer     0.806106
# 1  cancel_transfer  cancel_transfer     0.271031
# 2  cancel_transfer  cancel_transfer     0.695446
# 4  cancel_transfer  cancel_transfer     0.822643
# 5  cancel_transfer  cancel_transfer     0.646769

# %%
data_with_suggested_labels = pd.DataFrame(
    {"text": raw_texts, "given_label": labels, "suggested_label": label_issues["predicted_label"], "label_score": label_issues["label_score"]}
)
data_with_suggested_labels.iloc[lowest_quality_labels]
# Out:
#                                                                                                                                                                                                      text  \
# 981                                                                                                                                                                       i was charged for getting cash.
# 974                                                                                                                                                                       can i change my pin on holiday?
# 982                                                                                                                                                        will i be sent a new card before mine expires?
# 990                                                                                                                                                                                  Connection Timed Out
# 971                                                                                                                                                                  please tell me how to change my pin.
# 997                                                                           Sprinkle the rainbow sprinkles over the top of the salad and serve immediately. Enjoy your silly Rainbow Surprise Salad!NaN
# 980                                                                                                                                                  why do i see extra charges for withdrawing my money?
# 978                                                                                                                                                        why am i being charge a fee when using an atm?
# 989                                                                                                                                           <p><samp>File not found.<br>Press F1 to continue</samp></p>
# 998                                                                                                                                                                  https://github.com/cleanlab/cleanlab
# 985                                                                                                                       my card is almost expired.  how fast will i get a new one and what is the cost?
# 987                                                                                                                                                  Quaerat neque eius adipisci quiquia non consectetur?
# 983                                                                                                                                              are there any express fees if i want my new card faster?
# 966                                                                                                                                                                   why hasn't my payment shown up yet?
# 119                                                                                                                                                                  how do i avoid charges in the future
# 991                                                                                                                                 Would you rather fight one horse-sized duck or 100 duck-sized horses?
# 950                                                                                                                                                    how long does it take for a top up to be approved?
# 964                                             hi,  one of payment is still coming as pending for which i have already paid by card. i guess it did not processed, could you please check and update me.
# 994                                                                                                                                                 (A AND NOT B) OR (C AND NOT D) OR (B AND NOT C AND D)
# 970                                                                                                                                               what happens if a merchant doesn't accept  you payment?
# 984                                                                                                                                                       can i get a new card even though i am in china?
# 992                                                                                                                                          even_squares = filter(lambda x: x % 2 == 0, squared_numbers)
# 977                                                                                                                                         i need help finding the verification code on the top up card.
# 963                                                                                                                                                                      why is my payment still pending?
# 652                                                           i have tried to submit a transfer a couple of times now, and for some reason, it continues to be unsuccessful. do you know why this may be?
# 993                                                                                                                                                                          Nants ingonyama bagithi baba
# 367                                                                                                                                                        why did i get a different card then requested?
# 962                                                                                                                                                                    do you deliver the pin separately?
# 972                                                                                                                                                             what atms will allow me to change my pin?
# 973                                                                                                                                                                      is it possible to change my pin?
# 959                                                                                                                                                        how long does it take for a transfer to arrive
# 436  i was recently mugged and would like to know if i have to have access to the app to use your services and how i would go about setting up your services on a new device belonging to a current user?
# 979                                                                           so, i was just charged for my recent atm withdrawal and any withdrawal prior to this has been free. what is the issue here?
# 976                                                                                                                                          do you know how i can verify that i did a top-up to my card?
# 960                                                                                                                                                                             how do i find my new pin?
# 988                                                                                                                                                Etincidunt neque numquam adipisci ut dolor etincidunt?
# 957                                                                                                                                                                 i'm still waiting for my transaction.
# 958                                                                               how long do money transfers take? my friend really needs the money i sent a couple of hours ago but it's not there yet.
# 412                                                                                                                                   if i can't choose my card type will i be able to use it everywhere?
# 612                                                                                                                                              are there restrictions to transfers to certain accounts?
# 699                                                                                                                                   if i need more than cards will i have to pay a fee to receive them?
# 967                                                                                                                                                                          the card payment didn't work
# 591                                                                                                                                                                         why was my transfer stopped ?
# 965                                                                                                                                                                  why haven't i gotten my payment yet?
# 961                                                                                                                                                             when will i have access to my pin number?
# 954                                                                                                                           i tried to withdraw 40 pounds but only 20 came out. did you steal my money?
# 547                                                                         your atm pin can be changed at any visa or mastercard atm with pin services. certain countries don't support atm pin changes.
# 968                                                                                                                                                  why is a payment i made reverted back to my account?
# 81                                                                                                                                                                                     cancel transaction
# 480                                                                                                                                                    can i use your services without access to the app?
# 756                                                                                                                                                                    how much would an extra card cost?
# 558                                                                                                                                                    i think my pin has been compromised, what do i do?
# 999                                                                                                                                                              636C65616E6C616220697320617765736F6D6521
# 502                                                                                                                                                                     i want to replace my current pin.
# 557                                                                                                                                                                           i want to choose a new pin.
#
#                         given_label                 suggested_label  \
# 981            card_about_to_expire        card_payment_fee_charged
# 974         beneficiary_not_allowed                      change_pin
# 982         apple_pay_or_google_pay            card_about_to_expire
# 990         apple_pay_or_google_pay         beneficiary_not_allowed
# 971         beneficiary_not_allowed                      change_pin
# 997              getting_spare_card                      change_pin
# 980            card_about_to_expire        card_payment_fee_charged
# 978            card_about_to_expire        card_payment_fee_charged
# 989  supported_cards_and_currencies         beneficiary_not_allowed
# 998              visa_or_mastercard         beneficiary_not_allowed
# 985         apple_pay_or_google_pay            card_about_to_expire
# 987            card_about_to_expire         beneficiary_not_allowed
# 983         apple_pay_or_google_pay              getting_spare_card
# 966            lost_or_stolen_phone            card_about_to_expire
# 119        card_payment_fee_charged  supported_cards_and_currencies
# 991            lost_or_stolen_phone              getting_spare_card
# 950                 cancel_transfer              getting_spare_card
# 964            lost_or_stolen_phone                 cancel_transfer
# 994                      change_pin         beneficiary_not_allowed
# 970                      change_pin         beneficiary_not_allowed
# 984         apple_pay_or_google_pay            card_about_to_expire
# 992  supported_cards_and_currencies         apple_pay_or_google_pay
# 977              getting_spare_card         apple_pay_or_google_pay
# 963            lost_or_stolen_phone            card_about_to_expire
# 652         beneficiary_not_allowed                 cancel_transfer
# 993            card_about_to_expire         beneficiary_not_allowed
# 367              visa_or_mastercard        card_payment_fee_charged
# 962              visa_or_mastercard                 cancel_transfer
# 972         beneficiary_not_allowed                      change_pin
# 973         beneficiary_not_allowed                      change_pin
# 959  supported_cards_and_currencies            card_about_to_expire
# 436            lost_or_stolen_phone        card_payment_fee_charged
# 979            card_about_to_expire        card_payment_fee_charged
# 976              getting_spare_card         apple_pay_or_google_pay
# 960              visa_or_mastercard                      change_pin
# 988  supported_cards_and_currencies         beneficiary_not_allowed
# 957  supported_cards_and_currencies                      change_pin
# 958  supported_cards_and_currencies        card_payment_fee_charged
# 412              visa_or_mastercard         beneficiary_not_allowed
# 612         beneficiary_not_allowed        card_payment_fee_charged
# 699              getting_spare_card        card_payment_fee_charged
# 967                      change_pin         beneficiary_not_allowed
# 591         beneficiary_not_allowed            lost_or_stolen_phone
# 965            lost_or_stolen_phone         beneficiary_not_allowed
# 961              visa_or_mastercard  supported_cards_and_currencies
# 954        card_payment_fee_charged         beneficiary_not_allowed
# 547                      change_pin         beneficiary_not_allowed
# 968                      change_pin         beneficiary_not_allowed
# 81                  cancel_transfer  supported_cards_and_currencies
# 480            lost_or_stolen_phone  supported_cards_and_currencies
# 756              getting_spare_card        card_payment_fee_charged
# 558                      change_pin            lost_or_stolen_phone
# 999                 cancel_transfer         beneficiary_not_allowed
# 502                      change_pin              visa_or_mastercard
# 557                      change_pin              visa_or_mastercard
#
#      label_score
# 981     0.000005
# 974     0.000150
# 982     0.000219
# 990     0.000325
# 971     0.000511
# 997     0.000709
# 980     0.000947
# 978     0.001031
# 989     0.001195
# 998     0.002013
# 985     0.002398
# 987     0.003074
# 983     0.003304
# 966     0.003595
# 119     0.004013
# 991     0.004059
# 950     0.004559
# 964     0.004625
# 994     0.004902
# 970     0.005000
# 984     0.005923
# 992     0.006089
# 977     0.006881
# 963     0.007892
# 652     0.008213
# 993     0.008978
# 367     0.009618
# 962     0.009889
# 972     0.011235
# 973     0.011908
# 959     0.011961
# 436     0.012896
# 979     0.014244
# 976     0.014602
# 960     0.015805
# 988     0.017379
# 957     0.019303
# 958     0.022341
# 412     0.026293
# 612     0.027415
# 699     0.029156
# 967     0.031323
# 591     0.032885
# 965     0.038404
# 961     0.039393
# 954     0.040964
# 547     0.045157
# 968     0.045990
# 81      0.049447
# 480     0.053773
# 756     0.055700
# 558     0.061433
# 999     0.062079
# 502     0.062215
# 557     0.064150

# %%
highest_quality_labels = label_issues["label_score"].argsort()[::-1][:15].to_numpy()
data_with_suggested_labels.iloc[highest_quality_labels]
# Out:
#                                                   text  \
# 912                   need help with google pay top up
# 402                can i choose my visa or mastercard?
# 413                                visa or mastercard?
# 10                                cancel a transaction
# 369          can i choose between mastercard and visa?
# 146  there was a fee charged when i paid with my card.
# 94     i want to cancel the transaction i made earlier
# 353       can i choose from either visa or mastercard?
# 419          can i get a visa instead of a mastercard?
# 410                    can i get a visa or mastercard?
# 864                           google play top up help?
# 928                     google pay top up did not work
# 938     why is top up not working for my apple pay app
# 404       please give me both a visa and a mastercard.
# 643           why would my beneficiary not be allowed?
#
#                   given_label           suggested_label  label_score
# 912   apple_pay_or_google_pay   apple_pay_or_google_pay     0.999051
# 402        visa_or_mastercard        visa_or_mastercard     0.998505
# 413        visa_or_mastercard        visa_or_mastercard     0.998316
# 10            cancel_transfer           cancel_transfer     0.998040
# 369        visa_or_mastercard        visa_or_mastercard     0.997868
# 146  card_payment_fee_charged  card_payment_fee_charged     0.997449
# 94            cancel_transfer           cancel_transfer     0.997044
# 353        visa_or_mastercard        visa_or_mastercard     0.996566
# 419        visa_or_mastercard        visa_or_mastercard     0.996501
# 410        visa_or_mastercard        visa_or_mastercard     0.996221
# 864   apple_pay_or_google_pay   apple_pay_or_google_pay     0.996189
# 928   apple_pay_or_google_pay   apple_pay_or_google_pay     0.996161
# 938   apple_pay_or_google_pay   apple_pay_or_google_pay     0.995971
# 404        visa_or_mastercard        visa_or_mastercard     0.995964
# 643   beneficiary_not_allowed   beneficiary_not_allowed     0.995953

# %% [markdown]
# These are very clear label errors that cleanlab has identified in this data! Note that the `given_label` does not correctly reflect the intent of these requests, whoever produced this dataset made many mistakes that are important to address before modeling the data.

# %% [markdown]
# ### Outlier issues
#
# According to the report, our dataset contains some outliers.
# We can see which examples are outliers (and a numeric quality score quantifying how typical each example appears to be) via `get_issues`. We sort the resulting DataFrame by cleanlab's outlier quality score to see the most severe outliers in our dataset.

# %%
outlier_issues = lab.get_issues("outlier")
outlier_issues.sort_values("outlier_score").head()
# Out:
#      is_outlier_issue  outlier_score
# 994              True       0.676322
# 999              True       0.686193
# 989              True       0.711223
# 433              True       0.711974
# 990              True       0.713793

# %%
lowest_quality_outliers = outlier_issues["outlier_score"].argsort()[:35]

data_with_suggested_labels.iloc[lowest_quality_outliers]
# Out:
#                                                               text  \
# 994          (A AND NOT B) OR (C AND NOT D) OR (B AND NOT C AND D)
# 999                       636C65616E6C616220697320617765736F6D6521
# 989    <p><samp>File not found.<br>Press F1 to continue</samp></p>
# 433                                                  phone is gone
# 990                                           Connection Timed Out
# 81                                              cancel transaction
# 993                                   Nants ingonyama bagithi baba
# 998                           https://github.com/cleanlab/cleanlab
# 986              Voluptatem velit sit labore modi quiquia ipsum ut
# 662                                        payment did not process
# 10                                            cancel a transaction
# 49                                        cancelling a transaction
# 988         Etincidunt neque numquam adipisci ut dolor etincidunt?
# 987           Quaerat neque eius adipisci quiquia non consectetur?
# 347                                     can i obtained a visa card
# 995        const sum = numbers.reduce((acc, num) => acc + num, 0);
# 506                                                changing my pin
# 992   even_squares = filter(lambda x: x % 2 == 0, squared_numbers)
# 996      <button onclick="alert('Bad, example!')">Submit!</button>
# 60                                   please cancel the transaction
# 846                              want a new card what are the fees
# 461  phone is gone, dont want others to access account information
# 275                         do you accept credit cards from the us
# 956             i was not distributed all of cash that i requested
# 285                                  is american express accepted?
# 276                will you accept my credit card, it my only one.
# 189                              why and i being charged this fee?
# 69        i didn't want to make a transaction, i want to revert it
# 967                                   the card payment didn't work
# 906                                    how do i setup my apple pay
# 912                               need help with google pay top up
# 235   why is there a charged fee for debit or credit card payment?
# 387                              i need mastercard as well as visa
# 871                         how to activate google pay for top up?
# 828                                want to get a new card in china
#
#                         given_label                 suggested_label  \
# 994                      change_pin         beneficiary_not_allowed
# 999                 cancel_transfer         beneficiary_not_allowed
# 989  supported_cards_and_currencies         beneficiary_not_allowed
# 433            lost_or_stolen_phone            lost_or_stolen_phone
# 990         apple_pay_or_google_pay         beneficiary_not_allowed
# 81                  cancel_transfer  supported_cards_and_currencies
# 993            card_about_to_expire         beneficiary_not_allowed
# 998              visa_or_mastercard         beneficiary_not_allowed
# 986         apple_pay_or_google_pay         beneficiary_not_allowed
# 662         beneficiary_not_allowed         beneficiary_not_allowed
# 10                  cancel_transfer                 cancel_transfer
# 49                  cancel_transfer                 cancel_transfer
# 988  supported_cards_and_currencies         beneficiary_not_allowed
# 987            card_about_to_expire         beneficiary_not_allowed
# 347              visa_or_mastercard              visa_or_mastercard
# 995         beneficiary_not_allowed                 cancel_transfer
# 506                      change_pin                      change_pin
# 992  supported_cards_and_currencies         apple_pay_or_google_pay
# 996         apple_pay_or_google_pay         apple_pay_or_google_pay
# 60                  cancel_transfer                 cancel_transfer
# 846            card_about_to_expire            card_about_to_expire
# 461            lost_or_stolen_phone            lost_or_stolen_phone
# 275  supported_cards_and_currencies  supported_cards_and_currencies
# 956        card_payment_fee_charged        card_payment_fee_charged
# 285  supported_cards_and_currencies  supported_cards_and_currencies
# 276  supported_cards_and_currencies  supported_cards_and_currencies
# 189        card_payment_fee_charged        card_payment_fee_charged
# 69                  cancel_transfer                 cancel_transfer
# 967                      change_pin         beneficiary_not_allowed
# 906         apple_pay_or_google_pay         apple_pay_or_google_pay
# 912         apple_pay_or_google_pay         apple_pay_or_google_pay
# 235        card_payment_fee_charged        card_payment_fee_charged
# 387              visa_or_mastercard              visa_or_mastercard
# 871         apple_pay_or_google_pay         apple_pay_or_google_pay
# 828            card_about_to_expire            card_about_to_expire
#
#      label_score
# 994     0.004902
# 999     0.062079
# 989     0.001195
# 433     0.912998
# 990     0.000325
# 81      0.049447
# 993     0.008978
# 998     0.002013
# 986     0.266437
# 662     0.977302
# 10      0.998040
# 49      0.991731
# 988     0.017379
# 987     0.003074
# 347     0.594812
# 995     0.376334
# 506     0.900224
# 992     0.006089
# 996     0.850813
# 60      0.980328
# 846     0.746168
# 461     0.784996
# 275     0.990799
# 956     0.592119
# 285     0.232002
# 276     0.946161
# 189     0.616303
# 69      0.847634
# 967     0.031323
# 906     0.914806
# 912     0.999051
# 235     0.865141
# 387     0.840555
# 871     0.974104
# 828     0.756923

# %%
lowest_quality_outliers.to_numpy()
# Out:
# array([994, 999, 989, 433, 990,  81, 993, 998, 986, 662,  10,  49, 988,
#        987, 347, 995, 506, 992, 996,  60, 846, 461, 275, 956, 285, 276,
#        189,  69, 967, 906, 912, 235, 387, 871, 828])

# %% [markdown]
# We see that cleanlab has identified entries in this dataset that do not appear to be proper customer requests. Outliers in this dataset appear to be out-of-scope customer requests and other nonsensical text which does not make sense for intent classification. Carefully consider whether such outliers may detrimentally affect your data modeling, and consider removing them from the dataset if so.

# %% [markdown]
# ### Near-duplicate issues
#
# According to the report, our dataset contains some sets of nearly duplicated examples.
# We can see which examples are (nearly) duplicated (and a numeric quality score quantifying how dissimilar each example is from its nearest neighbor in the dataset) via `get_issues`. We sort the resulting DataFrame by cleanlab's near-duplicate quality score to see the text examples in our dataset that are most nearly duplicated.

# %%
duplicate_issues = lab.get_issues("near_duplicate")
duplicate_issues.sort_values("near_duplicate_score").head()
# Out:
#      is_near_duplicate_issue  near_duplicate_score  \
# 160                     True              0.006237
# 148                     True              0.006237
# 546                     True              0.006485
# 514                     True              0.006485
# 481                    False              0.008164
#
#                                     near_duplicate_sets  \
# 160  [148, 219, 234, 118, 201, 223, 125, 140, 978, 172]
# 148  [160, 219, 234, 223, 140, 118, 201, 125, 229, 978]
# 546  [514, 523, 570, 569, 458, 528, 757, 137, 539, 827]
# 514  [546, 523, 570, 757, 761, 569, 528, 527, 458, 137]
# 481  [475, 493, 486, 849, 466, 845, 434, 795, 468, 834]
#
#      distance_to_nearest_neighbor
# 160                      0.006237
# 148                      0.006237
# 546                      0.006485
# 514                      0.006485
# 481                      0.008165

# %% [markdown]
# The results above show which examples cleanlab considers nearly duplicated (rows where `is_near_duplicate_issue == True`). Here, we see that example 160 and 148 are nearly duplicated, as are example 546 and 514.
#
# Let's view these examples to see how similar they are.

# %%
data.iloc[[160, 148]]
# Out:
#                                                            text  \
# 160  why was i charged an additional fee when paying with card?
# 148       why was i charged an extra fee when paying with card?
#
#                         label
# 160  card_payment_fee_charged
# 148  card_payment_fee_charged

# %%
data.iloc[[546, 514]]
# Out:
#                                                 text       label
# 546    do i have to go to the bank to change my pin?  change_pin
# 514  do i have to go into the bank to change my pin?  change_pin

# %% [markdown]
# We see that these two sets of request are indeed very similar to one another! Including near duplicates in a dataset may have unintended effects on models, and be wary about splitting them across training/test sets.

# %% [markdown]
# As demonstrated above, cleanlab can automatically shortlist the most likely issues in your dataset to help you better curate your dataset for subsequent modeling. With this shortlist, you can decide whether to fix these label issues or remove nonsensical or duplicated examples from your dataset to obtain a higher-quality dataset for training your next ML model. cleanlab's issue detection can be run with outputs from *any* type of model you initially trained.
